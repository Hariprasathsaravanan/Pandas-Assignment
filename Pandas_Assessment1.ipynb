# %% [markdown]
# <a href="https://colab.research.google.com/github/Hariprasathsaravanan/Pandas-Assignment/blob/main/Pandas_Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
import pandas as pd
from glob import glob
result=sorted(glob('data/college_1.csv'))

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
data_dict=df[df['CodeKata Score']>15000]
data = pd.DataFrame(data_dict)
data.to_csv("expectations.csv")

data_dict1=df[(df['CodeKata Score']<10000)&(df['CodeKata Score']>15000)]
data1=pd.DataFrame(data_dict1)
data1.to_csv("Reached_expectations.csv")

data_dict2=df[(df['CodeKata Score']<7000)&(df['CodeKata Score']>10000)]
data2=pd.DataFrame(data_dict2)
data2.to_csv("Needs_Improvement.csv")

data_dict3=df[df['CodeKata Score']<7000]
data3 = pd.DataFrame(data_dict3)
data3.to_csv("Unsatisfactory.csv")

df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
data_dict4=df1[df1['CodeKata Score']>15000]
data4 = pd.DataFrame(data_dict4)
data4.to_csv("expectations-c2.csv")

data_dict5=df1[(df1['CodeKata Score']<10000)&(df1['CodeKata Score']>15000)]
data5=pd.DataFrame(data_dict5)
data5.to_csv("Reached_expectations-c2.csv")

data_dict6=df1[(df1['CodeKata Score']<7000)&(df1['CodeKata Score']>10000)]
data6=pd.DataFrame(data_dict6)
data6.to_csv("Needs_Improvement-c2.csv")

data_dict7=df1[df1['CodeKata Score']<7000]
data7 = pd.DataFrame(data_dict7)
data7.to_csv("Unsatisfactory-c2.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
avg_c1_gk=df['Previous Geekions'].mean()
avg_c2_gk=df1['Previous Geekions'].mean()
avg_c1_cs=df['CodeKata Score'].mean()
avg_c2_cs=df1['CodeKata Score'].mean()

# %% [markdown]
# ###### No of students participated

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
df['Name'].count()
df1['Name'].count()
# Out:
# 35

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
avg_c1_py=df['python'].mean()
avg_c2_py=df1['python'].mean()
avg_c1_ms=df['mysql'].mean()
avg_c2_ms=df1['mysql'].mean()
avg_c2_py_en=df1['python_en'].mean()
avg_c2_ct=df1['computational_thinking'].mean()

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
df2 = df.nlargest(3,['CodeKata Score'])
df3 = df1.nlargest(3,['CodeKata Score'])
print(df2)
print(df3)
# Out:
#           Name  python  ...                        Department  Rising
# 0    A.Dharani    82.0  ...  Computer Science and Engineering       0
# 1  V.JEEVITHA     82.0  ...  Computer Science and Engineering       0
# 2  HEMAVATHI.R   100.0  ...  Computer Science and Engineering       0
#
# [3 rows x 7 columns]
#                 Name  python  ...                              Department  Rising
# 0      ASHOK KUMAR K     100  ...  Electronics and Electrical Engineering       0
# 1            Chandru       0  ...        Computer Science and Engineering     340
# 2  Ganesh Ramkumar R      -1  ...        Computer Science and Engineering    2000
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
df2 = df.nlargest(3,['Previous Geekions'])
df3 = df1.nlargest(3,['Previous Geekions'])
print(df2)
print(df3)
# Out:
#           Name  python  ...                        Department  Rising
# 0    A.Dharani    82.0  ...  Computer Science and Engineering       0
# 1  V.JEEVITHA     82.0  ...  Computer Science and Engineering       0
# 2  HEMAVATHI.R   100.0  ...  Computer Science and Engineering       0
#
# [3 rows x 7 columns]
#               Name  python  ...                                 Department  Rising
# 0    ASHOK KUMAR K     100  ...     Electronics and Electrical Engineering       0
# 1          Chandru       0  ...           Computer Science and Engineering     340
# 3  Bodipudi Harini      -1  ...  Electronics and Communication Engineering       0
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')
plt.show()
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
df1.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('/content/drive/MyDrive/college_1.csv')
df.groupby(['Department']).sum().plot(kind='barh', y='CodeKata Score')
plt.show()
df1=pd.read_csv('/content/drive/MyDrive/college_2.csv')
df1.groupby(['Department']).sum().plot(kind='barh', y='CodeKata Score')
plt.show()
df.groupby(['Department']).sum().plot(kind='barh', y='Previous Geekions')
plt.show()
df1.groupby(['Department']).sum().plot(kind='barh', y='Previous Geekions')
plt.show()
